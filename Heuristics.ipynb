# %%
import numpy as np
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
# !ls repo
# Out:
# heuristics_result_2.pkl  heuristics_result_4.pkl

# %%
with open("repo/heuristics_result_4.pkl", 'rb') as f:
    res = pickle.load(f)
    #얘 4-16임.

# %%
df = pd.DataFrame(res).transpose()

# %%
df
# Out:
#            DM_DS_RTA_LC  DM_RTA_LC  DkC_RTA_LC  OPA_DA_LC  SM_DS_RTA_LC
# 4 16 0.10         10000      10000       10000      10000         10000
#      0.20         10000      10000       10000      10000         10000
#      0.30          9972       9972        9972      10000          9972
#      0.40          9913       9913        9913      10000          9913
#      0.50          9746       9746        9746      10000          9746
#      0.60          9502       9502        9497      10000          9497
#      0.70          9210       9213        9197      10000          9197
#      0.80          8801       8812        8780      10000          8775
#      0.90          8239       8297        8214      10000          8186
#      1.00          7558       7699        7562      10000          7462
#      1.10          6780       7044        6792      10000          6618
#      1.20          5859       6304        5955      10000          5656
# ...

# %%
df.to_csv("tmp.csv")
